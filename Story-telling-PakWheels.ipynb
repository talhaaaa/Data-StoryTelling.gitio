# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("pakwheels_used_car_data_v021.csv")
df
# Out:
#             id        city  assembly       body    make    model    year  \
# 0      7943732    Peshawar       NaN      Sedan  Toyota  Corolla  2013.0
# 1      7730314      Lahore       NaN      Sedan   Honda     City  2000.0
# 2      7943737      Lahore       NaN      Sedan  Toyota    Yaris  2021.0
# 3      7943733      Lahore       NaN  Hatchback  Suzuki    Swift  2017.0
# 4      7923484      Lahore       NaN      Sedan   Honda    Civic  2017.0
# ...        ...         ...       ...        ...     ...      ...     ...
# 77873  7775164       Daska       NaN      Sedan   Honda    Civic  2019.0
# 77874  7772775  Abbottabad  Imported  Hatchback  Suzuki     Alto  2015.0
# 77875  7773716  Faisalabad  Imported  Crossover      MG       HS  2021.0
# 77876  7322377      Quetta       NaN      Sedan  Suzuki   Baleno  2005.0
# 77877  7770898       Mandi  Imported      Sedan  Toyota  Corolla  1998.0
#
#        engine transmission    fuel            color     registered  mileage  \
# ...

# %%
df.head(20)
# Out:
#          id        city  assembly       body        make    model    year  \
# 0   7943732    Peshawar       NaN      Sedan      Toyota  Corolla  2013.0
# 1   7730314      Lahore       NaN      Sedan       Honda     City  2000.0
# 2   7943737      Lahore       NaN      Sedan      Toyota    Yaris  2021.0
# 3   7943733      Lahore       NaN  Hatchback      Suzuki    Swift  2017.0
# 4   7923484      Lahore       NaN      Sedan       Honda    Civic  2017.0
# 5   7943736      Vehari  Imported      Sedan       Honda    Civic  2010.0
# 6   7764683   Islamabad       NaN  Hatchback      Suzuki    Swift  2019.0
# 7   7943739  Faisalabad       NaN      Sedan       Honda     City  2018.0
# 8   7894559      Lahore  Imported  Hatchback    Daihatsu     Move  2019.0
# 9   7943724      Lahore       NaN      Sedan       Honda     City  2014.0
# 10  7907725      Lahore  Imported  Hatchback    Daihatsu     Move  2019.0
# 11  7943741      Lahore       NaN  Hatchback      Suzuki   Mehran  2019.0
# ...

# %%
df.tail(20)
# Out:
#             id        city  assembly         body     make    model    year  \
# 77858  7772371    Sargodha       NaN        Sedan   Toyota  Corolla  1999.0
# 77859  7772465      Gujrat       NaN        Sedan   Toyota    Yaris  2020.0
# 77860  7772242     Karachi       NaN        Sedan   Toyota  Corolla  2015.0
# 77861  7583555    Peshawar       NaN    Hatchback   Suzuki     Alto  2011.0
# 77862  7772641   Islamabad       NaN          SUV  Hyundai   Tucson  2021.0
# 77863  7772473     Karachi       NaN          NaN   Toyota  Corolla  1998.0
# 77864  7772486     Chakwal       NaN    Hatchback   Suzuki    Wagon  2021.0
# 77865  7772487     Haripur       NaN        Sedan   Toyota  Corolla  2010.0
# 77866  7772467   Islamabad       NaN        Sedan   Toyota  Corolla  2020.0
# 77867  7772648   Islamabad       NaN    Hatchback   Suzuki   Cultus  2002.0
# 77868  7772762   Islamabad  Imported          NaN   Suzuki    Every  2012.0
# ...

# %%
# Firstly we chane the type of col "engine" to string then remove .0 from col engine and add cc 

# df['engine'] = df['engine'].astype(str)
# df['engine'] = df['engine'].str.replace('.0', '.cc',regex=False)
# df

# %%
#Checking for null values in data set
df.isnull().sum()
# Out:
# id                  0
# city                0
# assembly        53689
# body             8904
# make                0
# model               0
# year             4779
# engine              3
# transmission        0
# fuel              906
# color            1480
# registered          0
# mileage             0
# price             583
# dtype: int64

# %%
df.describe()
# Out:
#                  id          year        engine         mileage         price
# count  7.787800e+04  73099.000000  77875.000000    77878.000000  7.729500e+04
# mean   7.809878e+06   2012.812610   1408.072550    91109.192750  3.883232e+06
# std    2.599523e+05      7.516685    704.459947    89275.336173  5.759480e+06
# min    2.748970e+05   1990.000000      3.000000        1.000000  1.100000e+05
# 25%    7.805760e+06   2007.000000   1000.000000    34000.000000  1.450000e+06
# 50%    7.865805e+06   2015.000000   1300.000000    80000.000000  2.700000e+06
# 75%    7.910334e+06   2019.000000   1600.000000   123456.000000  4.500000e+06
# max    7.943741e+06   2022.000000  15000.000000  1000000.000000  5.290000e+08

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77878 entries, 0 to 77877
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            77878 non-null  int64
#  1   city          77878 non-null  object
#  2   assembly      24189 non-null  object
#  3   body          68974 non-null  object
#  4   make          77878 non-null  object
#  5   model         77878 non-null  object
#  6   year          73099 non-null  float64
#  7   engine        77875 non-null  float64
#  8   transmission  77878 non-null  object
#  9   fuel          76972 non-null  object
#  10  color         76398 non-null  object
#  11  registered    77878 non-null  object
#  12  mileage       77878 non-null  int64
#  13  price         77295 non-null  float64
# dtypes: float64(3), int64(2), object(9)
# memory usage: 8.3+ MB

# %%
# Now we check the price of cars how much increase per year

custom_colors = sns.color_palette("coolwarm")
plt.figure(figsize=(12, 6))
sns.barplot(x = 'year' , y = 'price' , data = df  ,palette=custom_colors)
plt.xlabel('Manufacturing Year' , fontsize = 18)
plt.ylabel('price' , fontsize = 16)
plt.title('Average Car Prices by Year of Production', fontsize=16)
plt.xticks(rotation=45, fontsize=12)
plt.yticks(fontsize=12)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x='body', data=df, order=df['body'].value_counts().index)
plt.xlabel('Body Type')
plt.ylabel('Count')
plt.title('Distribution of Body Types')
plt.xticks(rotation=45)
plt.show()
